# %%
import os
import sys
import pandas as pd

# 1. Tự động dò tìm thư mục gốc của project (nơi có chứa thư mục 'src')
PROJECT_ROOT = os.getcwd()
while not os.path.exists(os.path.join(PROJECT_ROOT, 'src')):
    PROJECT_ROOT = os.path.dirname(PROJECT_ROOT)
    # Tránh loop vô hạn nếu lỡ để project ngoài desktop
    if PROJECT_ROOT == os.path.dirname(PROJECT_ROOT):
        break

# 2. Set thư mục làm việc và đưa vào sys.path
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
os.chdir(PROJECT_ROOT)

print(f"✅ Đã set thư mục làm việc tại: {os.getcwd()}")

# 3. Import hàm từ thư mục src
from src.models.supervised import train_and_evaluate

# 4. Đọc dữ liệu
try:
    df_ml = pd.read_csv('data/processed/hr_ml_encoded.csv') 
    print("✅ Đã load dữ liệu thành công!")
except FileNotFoundError:
    print("🚨 Lỗi: Không tìm thấy file, bác kiểm tra lại đường dẫn nhé!")

# --- THÊM DÒNG NÀY ĐỂ CHỐNG RÒ RỈ DỮ LIỆU ---
if 'Attrition_No' in df_ml.columns:
    df_ml = df_ml.drop(columns=['Attrition_No'])

# 5. Chạy mô hình (SỬA 'Attrition' THÀNH 'Attrition_Yes')
results, X_test, y_test = train_and_evaluate(df_ml, target_col='Attrition_Yes', config_path='configs/params.yaml')

# 6. In báo cáo
if results:
    for name, metrics in results.items():
        print("\n" + "="*50)
        print(f"BÁO CÁO CHI TIẾT: {name}")
        print(metrics['report'])
# Out:
# ✅ Đã set thư mục làm việc tại: C:\Users\vanqu\Nhom2_Data_08_Employee
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 21
#      18 print(f"✅ Đã set thư mục làm việc tại: {os.getcwd()}")
#      20 # 3. Import hàm từ thư mục src
# ---> 21 from src.models.supervised import train_and_evaluate
#      23 # 4. Đọc dữ liệu (Đổi lại đúng tên file của nhóm bác)
#      24 try:
#
# File ~\Nhom2_Data_08_Employee\src\models\supervised.py:5
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.ensemble import RandomForestClassifier
# ----> 5 from xgboost import XGBClassifier
#       6 from sklearn.metrics import classification_report, f1_score, precision_recall_curve, auc
#       8 def load_config(config_path="configs/params.yaml"):
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in d:\ungdung\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in d:\ungdung\lib\site-packages (from xgboost) (1.15.3)
# Downloading xgboost-3.2.0-py3-none-win_amd64.whl (101.7 MB)
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/101.7 MB 3.7 MB/s eta 0:00:28
#     --------------------------------------- 1.6/101.7 MB 5.2 MB/s eta 0:00:20
#    - -------------------------------------- 2.9/101.7 MB 5.4 MB/s eta 0:00:19
#    - -------------------------------------- 3.9/101.7 MB 5.8 MB/s eta 0:00:17
#    -- ------------------------------------- 5.2/101.7 MB 5.6 MB/s eta 0:00:18
#    -- ------------------------------------- 6.3/101.7 MB 5.7 MB/s eta 0:00:17
#    -- ------------------------------------- 7.3/101.7 MB 5.6 MB/s eta 0:00:17
#    --- ------------------------------------ 8.7/101.7 MB 5.6 MB/s eta 0:00:17
#    --- ------------------------------------ 10.0/101.7 MB 5.7 MB/s eta 0:00:17
#    ---- ----------------------------------- 11.3/101.7 MB 5.7 MB/s eta 0:00:16
#    ---- ----------------------------------- 12.3/101.7 MB 5.7 MB/s eta 0:00:16
#    ----- ---------------------------------- 13.6/101.7 MB 5.8 MB/s eta 0:00:16
#    ----- ---------------------------------- 14