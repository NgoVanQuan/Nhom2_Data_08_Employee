# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [2]</a>'.</span>

# %%
# Parameters
ML_DATA_PATH = "data/processed/hr_ml_encoded.csv"
TARGET_COL = "Attrition"

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
import os
import sys
import pandas as pd

# 1. Tự động dò tìm thư mục gốc của project (nơi có chứa thư mục 'src')
PROJECT_ROOT = os.getcwd()
while not os.path.exists(os.path.join(PROJECT_ROOT, 'src')):
    PROJECT_ROOT = os.path.dirname(PROJECT_ROOT)
    # Tránh loop vô hạn nếu lỡ để project ngoài desktop
    if PROJECT_ROOT == os.path.dirname(PROJECT_ROOT):
        break

# 2. Set thư mục làm việc và đưa vào sys.path
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
os.chdir(PROJECT_ROOT)

print(f"✅ Đã set thư mục làm việc tại: {os.getcwd()}")

# 3. Import hàm từ thư mục src
from src.models.supervised import train_and_evaluate

# 4. Đọc dữ liệu (Đổi lại đúng tên file của nhóm bác)
try:
    df_ml = pd.read_csv('data/processed/hr_ml_encoded.csv') # Sửa đúng chữ này thôi
    print("✅ Đã load dữ liệu thành công!")
except FileNotFoundError:
    print("🚨 Lỗi: Không tìm thấy file, bác kiểm tra lại đường dẫn nhé!")

# 5. Chạy mô hình
results, X_test, y_test = train_and_evaluate(df_ml, target_col='Attrition', config_path='configs/params.yaml')

# 6. In báo cáo
if results:
    for name, metrics in results.items():
        print("\n" + "="*50)
        print(f"BÁO CÁO CHI TIẾT: {name}")
        print(metrics['report'])
# Out:
# ✅ Đã set thư mục làm việc tại: E:\code\Nhom2_Data_08_Employee
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 21
#      18 print(f"✅ Đã set thư mục làm việc tại: {os.getcwd()}")
#      20 # 3. Import hàm từ thư mục src
# ---> 21 from src.models.supervised import train_and_evaluate
#      23 # 4. Đọc dữ liệu (Đổi lại đúng tên file của nhóm bác)
#      24 try:
#
# File E:\code\Nhom2_Data_08_Employee\src\models\supervised.py:5
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.ensemble import RandomForestClassifier
# ----> 5 from xgboost import XGBClassifier
#       6 from sklearn.metrics import classification_report, f1_score, precision_recall_curve, auc
#       8 def load_config(config_path="configs/params.yaml"):
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# !pip install xgboost
